# %% [markdown]
# ### Analise de desempenho do Algas 🌿

# %% [markdown]
# **Simulação do cenário da coleta de dados de velocidade do ar e pressão atmosférica**
#
# *1ª máquina com 8Gb de RAM e 4vCPUs*
#
# *2ª máquina com 4Gb de RAM e 2vCPUs*
#
# *3ª máquina com 2Gb de RAM e 1vCPUs*

# %% [markdown]
# **Analise do primeiro bloco de testes**

# %%
import pandas as pd
import matplotlib

# %%
large_f = pd.read_parquet("data_algas\large\large_f.parquet")
large_f.plot.line(subplots=True)
# Out:
# array([<AxesSubplot: >, <AxesSubplot: >, <AxesSubplot: >, <AxesSubplot: >],
#       dtype=object)

# %%
medium_f = pd.read_parquet("data_algas\medium\medium_f.parquet")
medium_f.plot.line(subplots=True)
# Out:
# array([<AxesSubplot: >, <AxesSubplot: >, <AxesSubplot: >, <AxesSubplot: >],
#       dtype=object)

# %%
small_f = pd.read_parquet("data_algas\small\small_f.parquet")
small_f.plot.line(subplots=True)
# Out:
# array([<AxesSubplot: >, <AxesSubplot: >, <AxesSubplot: >, <AxesSubplot: >],
#       dtype=object)

# %%
large_s = pd.read_parquet("data_algas\large\large_s.parquet")
large_s.plot.line(subplots=True)
# Out:
# array([<AxesSubplot: >, <AxesSubplot: >, <AxesSubplot: >, <AxesSubplot: >],
#       dtype=object)

# %%
medium_s = pd.read_parquet("data_algas\medium\medium_s.parquet")
medium_s.plot.line(subplots=True)
# Out:
# array([<AxesSubplot: >, <AxesSubplot: >, <AxesSubplot: >, <AxesSubplot: >],
#       dtype=object)

# %%
small_s = pd.read_parquet("data_algas\small\small_s.parquet")
small_s.plot.line(subplots=True)
# Out:
# array([<AxesSubplot: >, <AxesSubplot: >, <AxesSubplot: >, <AxesSubplot: >],
#       dtype=object)

# %%
large_t = pd.read_parquet("data_algas\large\large_t.parquet")
large_t.plot.line(subplots=True)
# Out:
# array([<AxesSubplot: >, <AxesSubplot: >, <AxesSubplot: >, <AxesSubplot: >],
#       dtype=object)

# %%
medium_t = pd.read_parquet("data_algas\medium\medium_t.parquet")
medium_t.plot.line(subplots=True)
# Out:
# array([<AxesSubplot: >, <AxesSubplot: >, <AxesSubplot: >, <AxesSubplot: >],
#       dtype=object)

# %%
small_t = pd.read_parquet("data_algas\small\small_t.parquet")
small_t.plot.line(subplots=True)
# Out:
# array([<AxesSubplot: >, <AxesSubplot: >, <AxesSubplot: >, <AxesSubplot: >],
#       dtype=object)

# %%
from matplotlib import pyplot as plt
def plot_block_ram_cpu(x, y1,y2,name):
    plt.title(name)

    plt.plot(
        x,
        y1,
        label = 'CPU usage',
        linestyle="-."
    )
    plt.plot(
        x,
        y2,
        label = 'RAM usage',
        linestyle="--"
    )
    plt.legend()
    plt.show()
  
def plot_block(x,y,name):
    plt.title(name)
    plt.xlabel('Espaço (Mb)', color= 'black')
    plt.ylabel('Tempo (s)', color= 'black')
    plt.plot(
        x,
        y,
    )

# %%
plot_block_ram_cpu(large_f['time_taken'], large_f['cpu_used'], large_f['ram_used'],"LARGE")

# %%
plot_block_ram_cpu(medium_f['time_taken'], medium_f['cpu_used'], medium_f['ram_used'], "MEDIUM")

# %%
plot_block_ram_cpu(small_f['time_taken'], small_f['cpu_used'], small_f['ram_used'], "SMALL")

# %%
plot_block_ram_cpu(large_s['time_taken'], large_s['cpu_used'], large_s['ram_used'],"LARGE")

# %%
plot_block_ram_cpu(medium_s['time_taken'], medium_s['cpu_used'], medium_s['ram_used'], "MEDIUM")

# %%
plot_block_ram_cpu(small_s['time_taken'], small_s['cpu_used'], small_s['ram_used'], "SMALL")

# %%
plot_block_ram_cpu(large_t['time_taken'], large_t['cpu_used'], large_t['ram_used'], "LARGE")

# %%
plot_block_ram_cpu(medium_t['time_taken'], medium_t['cpu_used'], medium_t['ram_used'],"MEDIUM")

# %%
plot_block_ram_cpu(small_t['time_taken'], small_t['cpu_used'], small_t['ram_used'],"SMALL")

# %%
plot_block(large_f['time_taken'],large_f['bytes_used'],"LARGE")

# %%
plot_block(medium_f['time_taken'],medium_f['bytes_used'], "MEDIUM")

# %%
plot_block(small_f['time_taken'],small_f['bytes_used'],"SMALL")

# %%
plot_block(large_s['time_taken'],large_s['bytes_used'], "LARGE")

# %%
plot_block(medium_s['time_taken'],medium_s['bytes_used'],"MEDIUM")

# %%
plot_block(small_s['bytes_used'],small_s['time_taken'], "SMALL")

# %%
plot_block(large_t['time_taken'],large_t['bytes_used'], "LARGE")

# %%
plot_block(medium_t['time_taken'],medium_t['bytes_used'], "MEDIUM")

# %%
plot_block(small_t['time_taken'],small_t['bytes_used'], "SMALL")
